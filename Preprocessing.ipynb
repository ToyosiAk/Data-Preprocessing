# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv(r"C:\Users\Toyosi\Documents\Training Montage\Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.csv")
df.head(5)
# Out:
#             Timestamp How old are you?  What industry do you work in?  \
# 0  4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22            25-34              Computing or Tech
# 2  4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41            25-34                     Nonprofits
# 4  4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
#
#                                   Job title  \
# 0        Research and Instruction Librarian
# 1  Change & Internal Communications Manager
# 2                      Marketing Specialist
# 3                           Program Manager
# 4                        Accounting Manager
#
#   If your job title needs additional context, please clarify here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
df.rename(columns= {"How old are you?": "Age Range", "What industry do you work in?": "Industry", "If your job title needs additional context, please clarify here:": "Job title context", "What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)": "Salary", "How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.": "Monetary Compensation", "Please indicate the currency": "Currency", "What country do you work in?": "Work_Country", "If you're in the U.S., what state do you work in?": "Work_U.S-State", "What city do you work in?":"Work_City", "How many years of professional work experience do you have overall?": "Work_Exp_Overall", "How many years of professional work experience do you have in your field?": "Work_Exp_Field","What is your highest level of education completed?": "Highest_Lvl_Edu", "What is your gender?": "Gender", "What is your race? (Choose all that apply.)": "Race_All"}, inplace= True)
df.head(5)
# Out:
#             Timestamp Age Range                       Industry  \
# 0  4/27/2021 11:02:10     25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22     25-34              Computing or Tech
# 2  4/27/2021 11:02:38     25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41     25-34                     Nonprofits
# 4  4/27/2021 11:02:42     25-34  Accounting, Banking & Finance
#
#                                   Job title Job title context  Salary  \
# 0        Research and Instruction Librarian               NaN  55,000
# 1  Change & Internal Communications Manager               NaN  54,600
# 2                      Marketing Specialist               NaN  34,000
# 3                           Program Manager               NaN  62,000
# 4                        Accounting Manager               NaN  60,000
#
#    Monetary Compensation Currency  \
# 0                    0.0      USD
# 1                 4000.0      GBP
# 2                    NaN      USD
# ...

# %%
df["Work_Country"].unique()
# Out:
# array(['United States', 'United Kingdom', 'US', 'USA', 'Canada',
#        'United Kingdom ', 'usa', 'UK', 'Scotland ', 'U.S.',
#        'United States ', 'The Netherlands', 'Australia ', 'Spain', 'us',
#        'Usa', 'England', 'finland', 'United States of America', 'France',
#        'United states', 'Scotland', 'USA ', 'United states ', 'Germany',
#        'UK ', 'united states', 'Ireland', 'India', 'Australia', 'Uk',
#        'United States of America ', 'U.S. ', 'canada', 'Canada ', 'U.S>',
#        'ISA', 'Argentina', 'Great Britain ', 'US ', 'United State',
#        'U.S.A', 'Denmark', 'U.S.A.', 'America', 'Netherlands',
#        'netherlands', 'England ', 'united states of america', 'Ireland ',
#        'Switzerland', 'Netherlands ', 'Bermuda', 'Us',
#        'The United States', 'United State of America', 'Germany ',
#        'Malaysia', 'Mexico ', 'United Stated', 'South Africa ', 'Belgium',
#        'Northern Ireland', 'u.s.', 'South Africa', 'UNITED STATES',
# ...

# %%
df["Work_Country"] =df["Work_Country"].replace({'United States': 'US', 'United Kingdom': 'GB', 'USA': 'US', 'Canada': 'CA', 'United Kingdom ': 'GB','usa': 'US', 'Scotland ': 'GB',  'U.S.': 'US',
       'United States ': 'US', 'The Netherlands': 'NL', 'Australia ': 'AU', 'Spain': 'ES', 'us': 'US',
       'Usa': 'US', 'England': 'GB', 'finland': 'FI', 'United States of America': 'US', 'France': 'FR',
       'United states': 'US', 'Scotland': 'GB', 'USA ': 'US', 'United states ': 'US', 'Germany': 'DE',
       'UK ': 'GB', 'united states': 'US', 'Ireland': 'IE', 'India': 'IN', 'Australia': 'AU', 'Uk': 'GB',
       'United States of America ': 'US', 'U.S. ': 'US', 'canada': 'CA', 'Canada ': 'CA', 'U.S>': 'US',
       'ISA': 'US', 'Argentina': 'AR', 'Great Britain ': 'GB', 'US ': 'US', 'United State': 'US',
       'U.S.A': 'US', 'Denmark': 'DK', 'U.S.A.': 'US', 'America': 'US', 'Netherlands': 'NL',
       'netherlands': 'NL', 'England ': 'GB', 'united states of america': 'US', 'Ireland ': 'IE',
       'Switzerland': 'CH', 'Netherlands ': 'NL', 'Bermuda': 'BM', 'Us': 'US',
       'The United States': 'US', 'United State of America': 'US', 'Germany ': 'DE',
       'Malaysia': 'MY', 'Mexico ': 'MX', 'United Stated': 'US', 'South Africa ': 'ZA', 'Belgium': 'BE',
       'Northern Ireland': 'GB', 'u.s.': 'US', 'South Africa': 'ZA', 'UNITED STATES': 'US',
       'united States': 'US', 'Sweden': 'SE', 'Hong Kong': 'HK', 'Kuwait': 'KW', 'Norway': 'NO',
       'Sri lanka': 'LK', 'USA-- Virgin Islands': 'VI', 'United Statws': 'US',
       'England/UK': 'GB', 'U.S': 'US',
       'Unites States ': 'US', 'Usa ': 'US', 'U.S.A. ': 'US', 'England, UK.': 'GB', 'Greece': 'GR',
       'Japan': 'JP', 'U. S. ': 'US', 'Britain ': 'GB', 'United Sates': 'US', 'Japan ': 'JP', 'Austria': 'AT',
       'Brazil': 'BR', 'Canada, Ottawa, ontario': 'CA', 'Sweden ': 'SE',
       'United States of American ': 'US', 'FRANCE': 'FR', 'Uniited States': 'US',
       'United Kingdom (England)': 'GB',
       'Worldwide (based in US but short term trips aroudn the world)': 'Global',
       'CANADA ': 'CA', 'Canadw': 'CA', 'Hungary': 'HU', 'Luxembourg': 'LU',
       'United Sates of America': 'US', 'ireland': 'IE',
       'United States (I work from home and my clients are all over the US/Canada/PR': 'US',
       'Colombia': 'CO', 'CANADA': 'CA', 'Unted States': 'US', 'germany': 'DE', 'United Statesp': 'US',
       'United Stattes': 'US', 'United Statea': 'US', 'United Kingdom.': 'GB', 'Mexico': 'MX',
       'New Zealand': 'NZ', 'Trinidad and Tobago': 'TT', 'Unites States': 'US',
       'United Statees': 'US', 'United kingdom': 'GB', 'Cayman Islands': 'KY',
       'UNited States': 'US', 'Can': 'CA',
       'I am located in Canada but I work for a company in the US': 'US',
       'United kingdom ': 'GB', 'Uniyed states': 'US', 'Uniyes States': 'US',
       'United States of Americas': 'US', 'Czech republic': 'CZ', 'Czechia': 'CZ',
       'Latvia': 'LV', 'Finland': 'FI', 'U. S.': 'US', 'Puerto Rico': 'PR', 'US of A': 'US', 'Rwanda': 'RW',
       'United States of america ': 'US', 'United Arab Emirates ': 'AE',
       'Bangladesh ': 'BG', 'Spain ': 'ES', 'U.K. ': 'GB', 'Romania': 'RO', 'U.SA': 'US',
       'United Kindom': 'GB', 'United Status': 'US', 'New Zealand ': 'NZ', ' U.S.': 'US', 'Serbia': 'RS', 'Philippines': 'PH', 'Russia ': 'RU',
       'Poland': 'PL', 'czech republic': 'CZ', 'England, UK': 'GB', 'Turkey': 'TR',
       'Canda': 'CA', 'Puerto Rico ': 'PR', 'Canada and USA': 'CA', 'Catalonia': 'ES', 'uk': 'GB', 'France ': 'FR',
       'Italy (South)': 'IT', 'Jersey, Channel islands': 'JE', 'Uk ': 'GB', 'China': 'CN',
       'Virginia': 'US', 'Afghanistan': 'AF', 'Israel': 'IL', 'U.s.': 'US', 'Great Britain': 'GB',
       'U.s.a.': 'US', 'USS': 'US', 'Denmark ': 'DK', 'Uniteed States': 'US',
       'New Zealand Aotearoa': 'NZ', 'U.K.': 'GB', 'Hartford': 'GB',
       'Japan, US Gov position': 'US', 'Csnada': 'CA', 'United Stares': 'US', 'New zealand': 'NZ',
       'Mainland China': 'CN', 'I.S.': 'IS', 'UK (Northern Ireland)': 'GB',
       'UK for U.S. company': 'US', ' US': 'US', 'Unites states ': 'US', 'Us ': 'US',
       'Hong Kong ': 'HK', 'Taiwan': 'TW', 'Canad': 'CA', 'Unite States': 'US', 'australia': 'AU',
       'The US': 'US', 'united states ': 'US', 'The Netherlands ': 'NL', 'Cambodia': 'KH',
       'United states of America ': 'US', 'Vietnam': 'VN', 'Singapore': 'SG',
       'South Korea': 'KR', 'Czech Republic ': 'CZ', 'Thailand': 'TH', 'Bangladesh': 'BD',
       'Lithuania': 'LT', 'Eritrea': 'ER', 'Indonesia': 'ID', 'Singapore ': 'SG',
       'For the United States government, but posted overseas': 'US',
       'Switzerland ': 'CH', 'United Kingdomk': 'GB', 'Italy': 'IT', ' New Zealand': 'NZ', 'Cuba': 'CU',
       'Slovenia': 'SI', 'Australi': 'AU', "Cote d'Ivoire": 'CI', 'united kingdom': 'GB',
       'From Romania, but for an US based company': 'US', 'Somalia': 'SO',
       'Wales (United Kingdom)': 'GB', 'England, Gb': 'GB', 'Czech Republic': 'CZ',
       'UnitedStates': 'US', 'Sri Lanka': 'LK', 'spain': 'ES', 'Danmark': 'DK',
       'U.K. (northern England)': 'GB', 'U.K': 'GB', 'the Netherlands': 'NL',
       'Nederland': 'NL', 'Slovakia': 'SK', 'United States of america': 'US', 'Portugal ': 'PT',
       'England, United Kingdom': 'GB', 'Sierra Leone': 'SL', 'Englang': 'GB',
       'United statew': 'US', 'UAE': 'AE', 'Belgium ': 'BG',
       'International ': 'GLOBAL', 'The Bahamas ': 'BS', 'Wales': 'GB',
       'Costa Rica': 'CR', ' United States': 'US', 'United Statues': 'US', 'Untied States': 'US',
       'USA (company is based in a US territory, I work remote)': 'US', 'Chile': 'CL',
       'denmark': 'DK', 'UK (England)': 'GB', 'UK, remote': 'GB', 'Scotland, UK': 'GB',
       'Unitied States': 'US', 'Norway ': 'NO', 'Qatar': 'QA', 'United Sttes': 'US',
       'Remote (philippines)': 'PH', 'Brazil ': 'BR', 'Unites kingdom ': 'GB',
       'South africa': 'ZA', 'Portugal': 'PT', 'united stated':'US',
       'United States Of America': 'US', 'Nigeria': 'NG', 'Panamá': 'PA',
       'Northern Ireland ': 'GB', 'england': 'GB', 'SWITZERLAND': 'CH',
       'Austria, but I work remotely for a Dutch/British company': 'GB',
       "I work for an US based company but I'm from Argentina.": 'US',
       'Uniter Statez': 'US', 'U. S ': 'US', 'United states of America': 'US',
       'Uruguay': 'UY', 'Pakistan': 'PK', 'Brasil': 'BR', 'USA tomorrow ': 'US', 'United Stateds': 'US', 'singapore': 'SG', 'usa ': 'US', 'Malaysia ': 'MY',
       'Uganda': 'UG', 'Malta': 'MT', 'Saudi Arabia': 'SA', 'Bulgaria': 'BG', 'Estonia': 'EE',
       'Morocco': 'MA', 'new zealand': 'NZ', 'Ecuador': 'EC', 'Zimbabwe': 'ZW', 'Ghana': 'GH',
       'San Francisco': 'US', 'Usat': 'US', '🇺🇸 ': 'US', 'Luxemburg': 'LU', 'Unitef Stated': 'US',
       'Wales, UK': 'GB', 'United Stares ': 'US', 'Croatia ': 'HR',
       'England, United Kingdom ': 'GB', 'United STates': 'US', 'USaa': 'US', 'uSA': 'US',
       'South Korea ': 'KR', 'The netherlands': 'NL', 'Ukraine ': 'UA', 'america': 'US',
       'switzerland': 'CH', 'United States- Puerto Rico': 'US',
       'Wales (UK)': 'GB', 'Isle of Man': 'IM', 'Northern Ireland, United Kingdom': 'GB',
       'California ': 'US', 'Australian ':'AU', 'México': 'MX', 'Jamaica': 'JM', 'uS': 'US', 'USD': 'US', 'the netherlands': 'NL',
       'japan': 'JP', 'Kenya': 'KE', 'Jordan': 'JO',
       'United Statss': 'US', 'ARGENTINA BUT MY ORG IS IN THAILAND': 'TH',
       'United states of america': 'US', 'UsA': 'US',
       'I work for a UAE-based organization, though I am personally in the US.': 'AE',
       'United  States': 'US', 'france': 'FR', 'Aotearoa New Zealand': 'NZ',
       'Cyprus': 'CY', 'hong konh': 'HK', 'United States is America': 'US', 'Liechtenstein': 'LI',
       'Company in Germany. I work from Pakistan.': 'DE', 'croatia': 'HR', 'Canadá': 'CA',
       'ENGLAND': 'GB', 'United States of American': 'US', 'U.S.A ': 'US', 'INDIA': 'IN',
       'Bosnia and Herzegovina': 'BA', 'NIGERIA': 'NG', 'Poland ': 'PL', 'pakistan': 'PK',
       'Nigeria ': 'NG', 'London': 'GB',
       'philippines': 'PH', 'Myanmar': 'MM', 'Burma': 'MM', 'Currently finance': 'US', 
       "We don't get raises, we get quarterly bonuses, but they periodically asses income in the area you work, so I got a raise because a 3rd party assessment showed I was paid too little for the area we were located": 'US',
       '$2,175.84/year is deducted for benefits': 'CA', 'bonus based on meeting yearly goals set w/ my supervisor': 'US',
        "I earn commission on sales. If I meet quota, I'm guaranteed another 16k min. Last year i earned an additional 27k. It's not uncommon for people in my space to earn 100k+ after commission. ": 'US',
        'I was brought in on this salary to help with the EHR and very quickly was promoted to current position but compensation was not altered. ': 'US',
        'US govt employee overseas, country withheld': 'US', 'From New Zealand but on projects across APAC': 'NZ', 'United y': 'US',
        'UK, but for globally fully remote company': 'GB', "USA, but for foreign gov't": 'US', 'na': 'US', 'Policy': 'CA', 'ss': 'US',
        'dbfemf': 'US', 'ibdia': 'GB', 'Contracts': 'US', 'U.A.': 'US', 'USAB': 'US', 'n/a (remote from wherever I want)': 'Remote',
        'europe': 'CZ', 'GLOBAL': 'Global', 'Congo': 'CG'})

# %%
df["Work_Country"].unique()
# Out:
# array(['US', 'GB', 'CA', 'UK', 'NL', 'AU', 'ES', 'FI', 'FR', 'DE', 'IE',
#        'IN', 'AR', 'DK', 'CH', 'BM', 'MY', 'MX', 'ZA', 'BE', 'SE', 'HK',
#        'KW', 'NO', 'LK', 'VI', 'GR', 'JP', 'AT', 'BR', 'Global', 'HU',
#        'LU', 'CO', 'NZ', 'TT', 'KY', 'CZ', 'LV', 'PR', 'RW', 'AE', 'BG',
#        'RO', 'RS', 'PH', 'RU', 'PL', 'UXZ', 'TR', 'IT', 'JE', 'CN', 'AF',
#        'IL', 'IS', 'TW', 'KH', 'VN', 'Remote', 'SG', 'KR', 'TH', 'BD',
#        'LT', 'ER', 'ID', 'CU', 'SI', 'CI', 'SO', 'SK', 'PT', 'SL', 'BS',
#        'CR', 'CL', 'QA', 'NG', 'PA', 'CG', 'UY', 'PK', 'UG', 'MT', 'SA',
#        'EE', 'MA', 'EC', 'ZW', 'GH', 'UA', 'HR', 'Y', 'IM', 'JM', 'KE',
#        'JO', 'CY', 'LI', 'BA', 'MM'], dtype=object)

# %%
df.drop([18944, 28036, 28049], axis= 0, inplace= True)

# %%
df["Work_Country"].unique()
# Out:
# array(['US', 'GB', 'CA', 'UK', 'NL', 'AU', 'ES', 'FI', 'FR', 'DE', 'IE',
#        'IN', 'AR', 'DK', 'CH', 'BM', 'MY', 'MX', 'ZA', 'BE', 'SE', 'HK',
#        'KW', 'NO', 'LK', 'VI', 'GR', 'JP', 'AT', 'BR', 'Global', 'HU',
#        'LU', 'CO', 'NZ', 'TT', 'KY', 'CZ', 'LV', 'PR', 'RW', 'AE', 'BG',
#        'RO', 'RS', 'PH', 'RU', 'PL', 'UXZ', 'TR', 'IT', 'JE', 'CN', 'AF',
#        'IL', 'IS', 'TW', 'KH', 'VN', 'Remote', 'SG', 'KR', 'TH', 'BD',
#        'LT', 'ER', 'ID', 'CU', 'SI', 'CI', 'SO', 'SK', 'PT', 'SL', 'BS',
#        'CR', 'CL', 'QA', 'NG', 'PA', 'CG', 'UY', 'PK', 'UG', 'MT', 'SA',
#        'EE', 'MA', 'EC', 'ZW', 'GH', 'UA', 'HR', 'Y', 'IM', 'JM', 'KE',
#        'JO', 'CY', 'LI', 'BA', 'MM'], dtype=object)

# %%
df[df['Job title'] == 'Intern']
# Out:
#                 Timestamp Age Range                      Industry Job title  \
# 8704   4/27/2021 16:30:43     18-24  Engineering or Manufacturing    Intern
# 8987   4/27/2021 17:01:08  under 18                   Health care    Intern
# 16801  4/28/2021 18:33:39     18-24  Engineering or Manufacturing    Intern
# 26750   9/9/2021 12:39:15     18-24                   Health care    Intern
# 27839  6/26/2022 12:13:46     18-24             Computing or Tech    Intern
# 28015   2/22/2024 7:27:47     18-24             Computing or Tech    Intern
#
#                                        Job title context  Salary  \
# 8704   Research at a research university (ie pays low...  55,120
# 8987                                                 NaN  29,120
# 16801                                                NaN  23,920
# 26750                                                NaN   30000
# 27839                                                NaN   62000
# ...
